# %% [markdown]
# <a href="https://colab.research.google.com/github/Owito/33-js-concepts/blob/master/PlatziNBA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/PlatziNBA.csv'

df = pd.read_csv(file_path)

df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#            Nombre     Género  Edad        Ciudad    Ingresos  \
# 0       Ana López   Femenino    32      Medellín  $2,500 USD
# 1     Juan García  Masculino    45      Santiago  $4,000 USD
# 2  Sofía Martínez   Femenino    28  Buenos Aires  $1,800 USD
# 3     Pedro Pérez  Masculino    50        Bogotá  $3,500 USD
# 4  María González   Femenino    24          Lima  $1,500 USD
#
#   Último producto adquirido Fecha de alta Satisfacción   Ocupación  \
# 0         Cuenta de ahorros    01/01/2023          4/5   Ingeniera
# 1        Tarjeta de crédito    15/07/2022          5/5      Médico
# 2         Préstamo personal    05/03/2024          3/5     Maestra
# 3            Seguro de vida    22/10/2021          5/5  Empresario
# 4         Cuenta de ahorros    10/11/2023          4/5  Estudiante
#
#   Estado civil Nivel educativo  Número de hijos           Canal
# ...

# %%
# Resumen de las variables numéricas
df.describe()
# Out:
#             Edad  Número de hijos
# count  40.000000        40.000000
# mean   38.225000         0.950000
# std    11.728745         1.060962
# min    21.000000         0.000000
# 25%    28.000000         0.000000
# 50%    37.500000         1.000000
# 75%    49.250000         2.000000
# max    60.000000         3.000000

# %%
# Cuenta la cantidad de clientes por ciudad
ciudad_count = df["Ciudad"].value_counts()
ciudad_count
# Out:
# Ciudad
# Buenos Aires        4
# Santiago            4
# Asunción            3
# Bogotá              3
# Lima                3
# Montevideo          3
# San José            3
# Quito               3
# Santo Domingo       3
# Ciudad de México    3
# La Paz              2
# Guadalajara         1
# Monterrey           1
# Medellín            1
# Bucaramanga         1
# Managua             1
# Celaya              1
# Name: count, dtype: int64

# %%
sns.displot(data=clientes, x="Edad", kind="hist", stat="density")
plt.title("Distribución de edades")
plt.show()

# %%
# Cuenta el número de clientes por género
genero_conteo = df["Género"].value_counts()

# Crea un gráfico de barras
plt.bar(genero_conteo.index, genero_conteo, color="#ff8c00")
plt.title("Distribución de género")
plt.xlabel("Género")
plt.ylabel("Número de clientes")
plt.show()

# %%
# Cuenta la cantidad de productos por tipo
producto_counts = df["Último producto adquirido"].value_counts()

# Crea un gráfico de barras
sns.barplot(x=producto_counts.index, y=producto_counts, color="purple")
plt.title("Productos favoritos")
plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(x=clientes["Edad"], y=clientes["Ingresos"])
plt.title("Relación entre edad e ingresos")
plt.show()
